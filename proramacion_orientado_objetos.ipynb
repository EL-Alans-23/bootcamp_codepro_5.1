# %%
class personaje():
    nombre = "defaul"
    vida = 100
    ataque = 0

    def __init__(self,nombre,ataque):
        self.nombre = nombre
        self.ataque = ataque
    
    def atributos (self):
        print(self.nombre )
        print("vida:",self.vida)
        print("ataque:",self.ataque)
    
    # def recibir_daño (self,enemigo):
    #     return self.vida - enemigo.ataque
    
    def atacar (self,enemigo):
        enemigo.vida -= self.ataque
    
prota = personaje("alans",7)
mi_enemigo = personaje("mi enemigo",10)
prota.atributos()
print("")
mi_enemigo.atributos()
print("")
prota.atacar(mi_enemigo)
print("")
mi_enemigo.atributos()
# Out:
# alans
# vida: 100
# ataque: 7
#
# mi enemigo
# vida: 100
# ataque: 10
#
#
# mi enemigo
# vida: 93
# ataque: 10
